# %%
# Impporting dependencies 
import pandas as pd

# %%
# Importing the cleaned data
heart_df = pd.read_csv('Resources/heart_clean.csv')
print(heart_df.shape)
heart_df.head()
# Out:
# (319795, 18)
#    HeartDisease Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# 0             0     Yes              No     No          No  Female
# 1             0      No              No    Yes          No  Female
# 2             0     Yes              No     No          No    Male
# 3             0      No              No     No          No  Female
# 4             0      No              No     No         Yes  Female
#
#   PhysicalActivity Asthma KidneyDisease SkinCancer             BMI  \
# 0              Yes    Yes            No        Yes     Underweight
# 1              Yes     No            No         No  Healthy_Weight
# 2              Yes    Yes            No         No      Overweight
# 3               No     No            No        Yes  Healthy_Weight
# 4              Yes     No            No         No  Healthy_Weight
#
#    PhysicalHealth  MentalHealth  AgeCategory   Race Diabetic  GenHealth  \
# 0               3            30        55-59  White      Yes  Very good
# 1               0             0  80 or older  White       No  Very good
# 2              20            30        65-69  White      Yes       Fair
# 3               0             0        75-79  White       No       Good
# 4              28             0        40-44  White       No  Very good
#
#    SleepTime
# 0          5
# 1          7
# 2          8
# 3          6
# 4          8

# %% [markdown]
# ### Undersampling

# %%
# Check balance of our target values
heart_df['HeartDisease'].value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %%
from sklearn.utils import resample
#create two different dataframe of majority and minority class 
df_majority = heart_df[(heart_df['HeartDisease']==0)] 
df_minority = heart_df[(heart_df['HeartDisease']==1)] 
# undersample majority class
df_majority_undersampled = resample(df_majority, 
                                 replace=True,    
                                 n_samples= 27373, # to match minority class
                                 random_state=42) 
# Combine minority class with undersampled majority
heart_df_undersampled = pd.concat([df_majority_undersampled, df_minority])

# %%
# print new undersampled df
print(heart_df_undersampled.shape)
heart_df_undersampled.head()
# Out:
# (54746, 18)
#         HeartDisease Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# 133490             0     Yes             Yes     No          No    Male
# 160740             0      No              No     No          No  Female
# 144281             0      No              No     No          No  Female
# 283354             0     Yes              No     No          No  Female
# 131213             0     Yes              No     No          No    Male
#
#        PhysicalActivity Asthma KidneyDisease SkinCancer             BMI  \
# 133490              Yes     No            No         No      Overweight
# 160740              Yes     No            No         No  Healthy_Weight
# 144281              Yes     No            No         No      Overweight
# 283354              Yes     No            No         No         Obesity
# 131213              Yes     No            No         No         Obesity
#
#         PhysicalHealth  MentalHealth AgeCategory      Race Diabetic  \
# 133490               0             0       50-54     White       No
# 160740               0             0       40-44     Black       No
# 144281              21             0       40-44  Hispanic       No
# 283354               2             2       65-69     Black       No
# 131213               0             0       70-74     White       No
#
#         GenHealth  SleepTime
# 133490  Excellent          7
# 160740       Good          8
# 144281       Fair          6
# 283354       Fair          6
# 131213       Good          6

# %%
# Check balance of our target values
heart_df_undersampled['HeartDisease'].value_counts()
# Out:
# 0    27373
# 1    27373
# Name: HeartDisease, dtype: int64

# %%
# Export dataframe to CSV without index
heart_df_undersampled.to_csv('Resources/heart_tableau_only.csv', index=False)
